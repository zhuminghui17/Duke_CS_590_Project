# %% [markdown]
# # Data Cleaning and Merge

# %% [markdown]
# 1. Use 3 million trimmed sample and connect it to weather dataset.

# %%
import pandas as pd
df = pd.read_csv('TripsRandomSample.csv')

# %%
df.shape
# Out:
# (3000000, 23)

# %%
df = df.drop(['Unnamed: 0', 'Unnamed: 0.1', 'Trip ID'], axis = 1)

# %%
df.columns
# Out:
# Index(['Trip Start Timestamp', 'Trip End Timestamp', 'Trip Seconds',
#        'Trip Miles', 'Pickup Census Tract', 'Dropoff Census Tract',
#        'Pickup Community Area', 'Dropoff Community Area', 'Fare', 'Tip',
#        'Additional Charges', 'Trip Total', 'Shared Trip Authorized',
#        'Trips Pooled', 'Pickup Centroid Latitude', 'Pickup Centroid Longitude',
#        'Pickup Centroid Location', 'Dropoff Centroid Latitude',
#        'Dropoff Centroid Longitude', 'Dropoff Centroid Location'],
#       dtype='object')

# %%
df.to_csv('dropped.csv')

# %%
from datetime import datetime
import pytz
from dateutil import parser

chicago_timezone = pytz.timezone('America/Chicago')

for i in ['Start', 'End']:
  df[f'Trip {i} UTC'] = df[f'Trip {i} Timestamp'].apply(lambda x: datetime.strptime(x, '%m/%d/%Y %I:%M:%S %p'))
  df[f'Trip {i} UTC'] = df[f'Trip {i} UTC'].apply(lambda x: pytz.utc.localize(x))
  df[f'Trip {i} Chicago'] = df[f'Trip {i} UTC'].apply(lambda x: x.astimezone(chicago_timezone))

# %%
df['Date'] = df['Trip Start Chicago'].apply(lambda x: str(x)[:10])
df['Hour'] = df['Trip Start Chicago'].apply(lambda x: str(x)[11:13])

# %%
df['time'] = df['Trip Start Chicago'].apply(lambda x: str(x)[:10] + 'T' + str(x)[11:13] + ':00')

# %%
df
# Out:
#            Trip Start Timestamp      Trip End Timestamp  Trip Seconds  \
# 0        03/24/2019 10:30:00 AM  03/24/2019 10:45:00 AM         790.0
# 1        03/12/2019 10:15:00 AM  03/12/2019 10:30:00 AM         568.0
# 2        03/19/2019 08:15:00 AM  03/19/2019 08:30:00 AM         593.0
# 3        03/21/2019 05:45:00 PM  03/21/2019 06:00:00 PM        1398.0
# 4        02/01/2019 08:45:00 PM  02/01/2019 09:00:00 PM         706.0
# ...                         ...                     ...           ...
# 2999995  01/26/2019 01:45:00 AM  01/26/2019 01:45:00 AM         215.0
# 2999996  03/01/2019 07:45:00 PM  03/01/2019 08:00:00 PM         376.0
# 2999997  03/04/2019 04:45:00 AM  03/04/2019 05:15:00 AM        1382.0
# 2999998  01/07/2019 09:00:00 AM  01/07/2019 09:30:00 AM        2138.0
# 2999999  03/11/2019 06:00:00 AM  03/11/2019 06:15:00 AM        1124.0
#
#          Trip Miles  Pickup Census Tract  Dropoff Census Tract  \
# 0               5.6                  NaN                   NaN
# 1               1.4         1.703128e+10          1.703108e+10
# 2               2.5         1.703148e+10          1.703184e+10
# 3               2.4         1.703183e+10          1.703108e+10
# 4               2.7         1.703108e+10          1.703106e+10
# ...             ...                  ...                   ...
# 2999995         1.0         1.703108e+10          1.703183e+10
# 2999996         1.3         1.703107e+10          1.703107e+10
# 2999997        15.6         1.703106e+10          1.703198e+10
# 2999998         7.4         1.703138e+10          1.703184e+10
# 2999999         6.9         1.703184e+10          1.703108e+10
#
#          Pickup Community Area  Dropoff Community Area  Fare  Tip  ...  \
# 0                         48.0                    53.0  10.0  0.0  ...
# 1                         28.0                     8.0   5.0  2.0  ...
# 2                         48.0                    44.0   7.5  0.0  ...
# 3                         28.0                     8.0   5.0  0.0  ...
# 4                          8.0                     6.0   7.5  1.0  ...
# ...                        ...                     ...   ...  ...  ...
# 2999995                    8.0                     7.0   2.5  0.0  ...
# 2999996                    7.0                     7.0   5.0  0.0  ...
# 2999997                    6.0                    76.0  20.0  0.0  ...
# 2999998                   38.0                    32.0  12.5  0.0  ...
# 2999999                   30.0                     8.0  12.5  1.0  ...
#
#          Dropoff Centroid Latitude  Dropoff Centroid Longitude  \
# 0                        41.673820                  -87.635740
# 1                        41.895033                  -87.619711
# 2                        41.742488                  -87.630045
# 3                        41.892042                  -87.631864
# 4                        41.934659                  -87.646730
# ...                            ...                         ...
# 2999995                  41.914747                  -87.654007
# 2999996                  41.914616                  -87.631717
# 2999997                  41.979071                  -87.903040
# 2999998                  41.880994                  -87.632746
# 2999999                  41.899156                  -87.626211
#
#                     Dropoff Centroid Location            Trip Start UTC  \
# 0        POINT (-87.6357397768 41.6738199043) 2019-03-24 10:30:00+00:00
# 1        POINT (-87.6197106717 41.8950334495) 2019-03-12 10:15:00+00:00
# 2        POINT (-87.6300448953 41.7424875717) 2019-03-19 08:15:00+00:00
# 3        POINT (-87.6318639497 41.8920421365) 2019-03-21 17:45:00+00:00
# 4        POINT (-87.6467297286 41.9346591566) 2019-02-01 20:45:00+00:00
# ...                                       ...                       ...
# 2999995  POINT (-87.6540070286 41.9147473049) 2019-01-26 01:45:00+00:00
# 2999996  POINT (-87.6317173661 41.9146162864) 2019-03-01 19:45:00+00:00
# 2999997  POINT (-87.9030396611 41.9790708201) 2019-03-04 04:45:00+00:00
# 2999998  POINT (-87.6327464887 41.8809944707) 2019-01-07 09:00:00+00:00
# 2999999  POINT (-87.6262105324 41.8991556134) 2019-03-11 06:00:00+00:00
#
#                Trip Start Chicago              Trip End UTC  \
# 0       2019-03-24 05:30:00-05:00 2019-03-24 10:45:00+00:00
# 1       2019-03-12 05:15:00-05:00 2019-03-12 10:30:00+00:00
# 2       2019-03-19 03:15:00-05:00 2019-03-19 08:30:00+00:00
# 3       2019-03-21 12:45:00-05:00 2019-03-21 18:00:00+00:00
# 4       2019-02-01 14:45:00-06:00 2019-02-01 21:00:00+00:00
# ...                           ...                       ...
# 2999995 2019-01-25 19:45:00-06:00 2019-01-26 01:45:00+00:00
# 2999996 2019-03-01 13:45:00-06:00 2019-03-01 20:00:00+00:00
# 2999997 2019-03-03 22:45:00-06:00 2019-03-04 05:15:00+00:00
# 2999998 2019-01-07 03:00:00-06:00 2019-01-07 09:30:00+00:00
# 2999999 2019-03-11 01:00:00-05:00 2019-03-11 06:15:00+00:00
#
#                  Trip End Chicago        Date  Hour              time
# 0       2019-03-24 05:45:00-05:00  2019-03-24    05  2019-03-24T05:00
# 1       2019-03-12 05:30:00-05:00  2019-03-12    05  2019-03-12T05:00
# 2       2019-03-19 03:30:00-05:00  2019-03-19    03  2019-03-19T03:00
# 3       2019-03-21 13:00:00-05:00  2019-03-21    12  2019-03-21T12:00
# 4       2019-02-01 15:00:00-06:00  2019-02-01    14  2019-02-01T14:00
# ...                           ...         ...   ...               ...
# 2999995 2019-01-25 19:45:00-06:00  2019-01-25    19  2019-01-25T19:00
# 2999996 2019-03-01 14:00:00-06:00  2019-03-01    13  2019-03-01T13:00
# 2999997 2019-03-03 23:15:00-06:00  2019-03-03    22  2019-03-03T22:00
# 2999998 2019-01-07 03:30:00-06:00  2019-01-07    03  2019-01-07T03:00
# 2999999 2019-03-11 01:15:00-05:00  2019-03-11    01  2019-03-11T01:00
#
# [3000000 rows x 27 columns]

# %%
print(min(df['Date']))
print(max(df['Date']))
# Out:
# 2018-10-31
# 2022-12-31

# %%
weather = pd.read_csv('archive.csv', skiprows=3)

# %%
weather
# Out:
#                    time  temperature_2m (°C)  relativehumidity_2m (%)  \
# 0      2018-10-31T00:00                 12.9                       96
# 1      2018-10-31T01:00                 11.3                       94
# 2      2018-10-31T02:00                 11.2                       93
# 3      2018-10-31T03:00                 10.8                       91
# 4      2018-10-31T04:00                 10.4                       89
# ...                 ...                  ...                      ...
# 36547  2022-12-31T19:00                  0.6                       91
# 36548  2022-12-31T20:00                  0.9                       92
# 36549  2022-12-31T21:00                  1.0                       92
# 36550  2022-12-31T22:00                  1.0                       93
# 36551  2022-12-31T23:00                  1.0                       92
#
#        precipitation (mm)  rain (mm)  snowfall (cm)  cloudcover (%)  \
# 0                     2.2        2.2            0.0             100
# 1                     0.8        0.8            0.0             100
# 2                     1.5        1.5            0.0             100
# 3                     3.2        3.2            0.0             100
# 4                     1.1        1.1            0.0             100
# ...                   ...        ...            ...             ...
# 36547                 0.0        0.0            0.0              80
# 36548                 0.0        0.0            0.0              73
# 36549                 0.0        0.0            0.0              81
# 36550                 0.0        0.0            0.0              89
# 36551                 0.0        0.0            0.0              75
#
#        windspeed_10m (km/h)  winddirection_10m (°)
# 0                      13.8                    354
# 1                      15.8                      1
# 2                      19.6                    354
# 3                      20.9                    345
# 4                      14.6                    351
# ...                     ...                    ...
# 36547                   9.9                    134
# 36548                  12.8                    140
# 36549                  13.4                    144
# 36550                  13.6                    158
# 36551                  15.0                    169
#
# [36552 rows x 9 columns]

# %%
df = pd.merge(df, weather, on="time")

# %%
df
# Out:
#            Trip Start Timestamp      Trip End Timestamp  Trip Seconds  \
# 0        03/24/2019 10:30:00 AM  03/24/2019 10:45:00 AM         790.0
# 1        03/24/2019 10:15:00 AM  03/24/2019 10:30:00 AM         664.0
# 2        03/24/2019 10:15:00 AM  03/24/2019 10:30:00 AM        1034.0
# 3        03/24/2019 10:30:00 AM  03/24/2019 11:00:00 AM        2061.0
# 4        03/24/2019 10:15:00 AM  03/24/2019 10:15:00 AM         503.0
# ...                         ...                     ...           ...
# 2999995  12/21/2022 02:00:00 AM  12/21/2022 02:00:00 AM         421.0
# 2999996  12/21/2022 02:00:00 AM  12/21/2022 02:00:00 AM         183.0
# 2999997  12/21/2022 02:00:00 AM  12/21/2022 02:15:00 AM         409.0
# 2999998  12/21/2022 02:00:00 AM  12/21/2022 02:00:00 AM         548.0
# 2999999  12/21/2022 02:15:00 AM  12/21/2022 02:30:00 AM         719.0
#
#          Trip Miles  Pickup Census Tract  Dropoff Census Tract  \
# 0               5.6                  NaN                   NaN
# 1               5.8         1.703183e+10          1.703108e+10
# 2               4.6                  NaN                   NaN
# 3              17.6         1.703108e+10          1.703198e+10
# 4               1.2         1.703108e+10          1.703108e+10
# ...             ...                  ...                   ...
# 2999995         2.4                  NaN                   NaN
# 2999996         0.9         1.703183e+10          1.703183e+10
# 2999997         2.0                  NaN                   NaN
# 2999998         2.4         1.703106e+10          1.703105e+10
# 2999999         3.4                  NaN                   NaN
#
#          Pickup Community Area  Dropoff Community Area  Fare  Tip  ...  Hour  \
# 0                         48.0                    53.0  10.0  0.0  ...    05
# 1                          3.0                     8.0  10.0  2.0  ...    05
# 2                         19.0                    24.0   7.5  0.0  ...    05
# 3                          8.0                    76.0  25.0  5.0  ...    05
# 4                          8.0                     8.0   5.0  0.0  ...    05
# ...                        ...                     ...   ...  ...  ...   ...
# 2999995                   24.0                    24.0   7.5  0.0  ...    20
# 2999996                   28.0                    28.0   5.0  0.0  ...    20
# 2999997                   32.0                    28.0   7.5  0.0  ...    20
# 2999998                    6.0                     5.0  15.0  0.0  ...    20
# 2999999                    4.0                    16.0  17.5  3.0  ...    20
#
#                      time  temperature_2m (°C)  relativehumidity_2m (%)  \
# 0        2019-03-24T05:00                  3.6                       73
# 1        2019-03-24T05:00                  3.6                       73
# 2        2019-03-24T05:00                  3.6                       73
# 3        2019-03-24T05:00                  3.6                       73
# 4        2019-03-24T05:00                  3.6                       73
# ...                   ...                  ...                      ...
# 2999995  2022-12-20T20:00                 -2.1                       71
# 2999996  2022-12-20T20:00                 -2.1                       71
# 2999997  2022-12-20T20:00                 -2.1                       71
# 2999998  2022-12-20T20:00                 -2.1                       71
# 2999999  2022-12-20T20:00                 -2.1                       71
#
#          precipitation (mm)  rain (mm) snowfall (cm)  cloudcover (%)  \
# 0                       0.0        0.0           0.0              62
# 1                       0.0        0.0           0.0              62
# 2                       0.0        0.0           0.0              62
# 3                       0.0        0.0           0.0              62
# 4                       0.0        0.0           0.0              62
# ...                     ...        ...           ...             ...
# 2999995                 0.0        0.0           0.0              96
# 2999996                 0.0        0.0           0.0              96
# 2999997                 0.0        0.0           0.0              96
# 2999998                 0.0        0.0           0.0              96
# 2999999                 0.0        0.0           0.0              96
#
#          windspeed_10m (km/h) winddirection_10m (°)
# 0                         6.6                   209
# 1                         6.6                   209
# 2                         6.6                   209
# 3                         6.6                   209
# 4                         6.6                   209
# ...                       ...                   ...
# 2999995                  11.7                   313
# 2999996                  11.7                   313
# 2999997                  11.7                   313
# 2999998                  11.7                   313
# 2999999                  11.7                   313
#
# [3000000 rows x 35 columns]

# %%
df.columns
# Out:
# Index(['Trip Start Timestamp', 'Trip End Timestamp', 'Trip Seconds',
#        'Trip Miles', 'Pickup Census Tract', 'Dropoff Census Tract',
#        'Pickup Community Area', 'Dropoff Community Area', 'Fare', 'Tip',
#        'Additional Charges', 'Trip Total', 'Shared Trip Authorized',
#        'Trips Pooled', 'Pickup Centroid Latitude', 'Pickup Centroid Longitude',
#        'Pickup Centroid Location', 'Dropoff Centroid Latitude',
#        'Dropoff Centroid Longitude', 'Dropoff Centroid Location',
#        'Trip Start UTC', 'Trip Start Chicago', 'Trip End UTC',
#        'Trip End Chicago', 'Date', 'Hour', 'time', 'temperature_2m (°C)',
#        'relativehumidity_2m (%)', 'precipitation (mm)', 'rain (mm)',
#        'snowfall (cm)', 'cloudcover (%)', 'windspeed_10m (km/h)',
#        'winddirection_10m (°)'],
#       dtype='object')

# %% [markdown]
# 2. find community level (or census tract level) data of Chicago : income, crime, etc. Merge it.

# %%
import pandas as pd
df = pd.read_csv('dataWithWeather.csv')

# %%
communityData = pd.read_csv('chicagoCommunityData.csv')

# %%
communityPickUp = communityData.copy()
communityDropoff = communityData.copy()

# %%
communityPickUp = communityPickUp[['GEOID', 'GEOG', '2020_POP', 'TOT_COMM', "CARPOOL", 'INCPERCAP']]
communityDropoff = communityDropoff[['GEOID', 'GEOG', '2020_POP', 'TOT_COMM', "CARPOOL", 'INCPERCAP']]

# %%
communityPickUp.rename(columns={'GEOID': 'Pickup Community Area', 'GEOG': 'Pickup Community Name'}, inplace=True)
communityDropoff.rename(columns={'GEOID': 'Dropoff Community Area', 'GEOG': 'Dropoff Community Name'}, inplace=True)

# %%
communityPickUp['CarpoolPerComm'] = communityPickUp['CARPOOL'] / communityPickUp['TOT_COMM']
communityDropoff['CarpoolPerComm'] = communityDropoff['CARPOOL'] / communityDropoff['TOT_COMM']

communityPickUp.rename(columns={'2020_POP': 'PopPickup', 'CarpoolPerComm': 'CarpoolPerCommPickup', 'INCPERCAP': 'IncomePickup'}, inplace=True)
communityDropoff.rename(columns={'2020_POP': 'PopDropoff', 'CarpoolPerComm': 'CarpoolPerCommDropoff', 'INCPERCAP': 'IncomeDropoff'}, inplace=True)

# %%
communityPickUp = communityPickUp.drop(['TOT_COMM', 'CARPOOL'], axis=1)
communityDropoff= communityDropoff.drop(['TOT_COMM', 'CARPOOL'], axis =1)

# %%
df = pd.merge(df, communityPickUp, on = 'Pickup Community Area', how='left')

# %%
df = pd.merge(df, communityDropoff, on = 'Dropoff Community Area', how='left')

# %%
df.to_csv('dataWithCommunityInfo.csv')

# %%
df['Pickup Census Tract'].isna().sum() /3000000
# Out:
# 0.38869533333333334

# %%
df['Pickup Community Area'].isna().sum() /3000000
# Out:
# 0.073448

# %% [markdown]
# ## Tipping

# %%
import pandas as pd

df = pd.read_csv('dataWithCommunityInfo.csv')

# %%
# Subsetting the data for time
df['date'] = df['Trip Start Timestamp'].str[:10]   
df['time_start'] = df['Trip Start Timestamp'].str[11:16]
df['ampm'] = df['Trip Start Timestamp'].str[-2:]

# %%
from datetime import datetime
df['date2'] = pd.to_datetime(df['date'], format='%m/%d/%Y')
df['tipperc'] = (df['Tip']/(df['Fare'] + df['Additional Charges']))*100
df['count'] = 1

# Checking the number of NA. Some minor absence from Tip, Trip Miles, and Trip seconds. We're deleting them. (around 3000 obs, or 0.1%)
df = df.dropna(subset=['Trip Seconds', 'Tip', 'Trip Miles', 'Fare', 'tipperc'])

# Also dropping some stuff where values doesnt make sense
df = df[df['tipperc'] < 10000]

# Extracting the weekdays
df['day'] = df['date2'].dt.weekday

# %%
df['income'] = df[['IncomePickup','IncomeDropoff']].mean(axis = 1, )

# %%
len(df['income'])
# Out:
# 2996043

# %%
df['income'].rank(ascending=False, na_option = 'keep')
# Out:
# 0          2497484.0
# 1          1073037.0
# 2          1965802.0
# 3          1161958.5
# 4            72655.5
#              ...
# 2999995    1229129.0
# 2999996    1585764.5
# 2999997     944995.0
# 2999998     907923.5
# 2999999    1990699.0
# Name: income, Length: 2996043, dtype: float64

# %%
minIncome = min(income['IncomePickup'])
maxIncome = max(income['IncomePickup'])
income['IncomeRank'] = income['IncomePickup'].apply(lambda x: np.floor((x - minIncome)/(maxIncome-minIncome) * 5))
income
# Out:
#     IncomePickup  IncomeRank
# 0    35883.58973         1.0
# 1    42111.65248         1.0
# 2    21611.65496         0.0
# 3   105016.51420         5.0
# 4    59634.86515         2.0
# ..           ...         ...
# 73   24226.59958         0.0
# 74   16193.12890         0.0
# 75   27694.54333         0.0
# 76   21933.78360         0.0
# 77   19183.58743         0.0
#
# [78 rows x 2 columns]

# %%
df = pd.merge(df, income, how='left', on='IncomePickup')

# %%
# Create a mean for tip percentage
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 8))
for i in income.IncomeRank.unique(): 
    grouped_mean = df[df['IncomeRank'] == i].groupby([df.date2]).mean()
    grouped_sum = df[df['IncomeRank'] == i].groupby([df.date2]).sum()
    rolling_avg = grouped_mean.rolling(window=7).mean()
    rolling_sum = grouped_sum.rolling(window=7).mean()
    plt.plot(grouped_sum.index, rolling_sum['count'], label = f'Income Level: {i}',linewidth= '0.8')


plt.xlabel('Date')
plt.ylabel('Number of Trips')
plt.legend()
plt.title('7-days rolling average for Number of trips, Classfied by Pick Up Community Income Level')

plt.axvline(pd.to_datetime('03/13/2020', format='%m/%d/%Y'), color='g', linestyle='--')

# Some events (to discuss)
# National Emergency
plt.axvline(pd.to_datetime('03/13/2020', format='%m/%d/%Y'), color='g', linestyle='--')
plt.text(pd.to_datetime('03/20/2020', format='%m/%d/%Y'), 700, 'US COVID-19 National Emergency', color = 'g' )

# https://chicago.suntimes.com/coronavirus/2020/5/28/21273554/coronvirus-chicago-reopening-businesses-restaurants-pandemic-rules-lightfoot
plt.axvline(pd.to_datetime('06/3/2020', format='%m/%d/%Y'), color='brown', linestyle='--')
plt.text(pd.to_datetime('06/13/2020', format='%m/%d/%Y'), 50, 'Chicago COVID-19 Reopening', color = 'brown' )
# Out:
# Text(2020-06-13 00:00:00, 50, 'Chicago COVID-19 Reopening')

# %%
# Create a mean for tip percentage
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 8))
for i in income.IncomeRank.unique(): 
    grouped_mean = df[df['IncomeRank'] == i].groupby([df.date2]).mean()
    grouped_sum = df[df['IncomeRank'] == i].groupby([df.date2]).sum()
    rolling_avg = grouped_mean.rolling(window=7).mean()
    rolling_sum = grouped_sum.rolling(window=7).mean()
    plt.plot(rolling_avg.index, rolling_avg['tipperc'], label = f'Income Level: {i}',linewidth= '0.5')


plt.xlabel('Date')
plt.ylabel('Percentage of Tip')
plt.legend()
plt.title('7-days rolling average - Daily Percentage of Tip, Classfied by Pick Up Community Income Level')

plt.axvline(pd.to_datetime('03/13/2020', format='%m/%d/%Y'), color='g', linestyle='--')

# Some events (to discuss)
# National Emergency
plt.axvline(pd.to_datetime('03/13/2020', format='%m/%d/%Y'), color='g', linestyle='--')
plt.text(pd.to_datetime('03/20/2020', format='%m/%d/%Y'), 7, 'US COVID-19 National Emergency', color = 'g' )

# https://chicago.suntimes.com/coronavirus/2020/5/28/21273554/coronvirus-chicago-reopening-businesses-restaurants-pandemic-rules-lightfoot
plt.axvline(pd.to_datetime('06/3/2020', format='%m/%d/%Y'), color='brown', linestyle='--')
plt.text(pd.to_datetime('06/13/2020', format='%m/%d/%Y'), 1, 'Chicago COVID-19 Reopening', color = 'brown' )
# Out:
# Text(2020-06-13 00:00:00, 1, 'Chicago COVID-19 Reopening')
